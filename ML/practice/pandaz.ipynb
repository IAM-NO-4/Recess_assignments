# %%
import pandas as pd

# %%
nums = pd.Series([1,2,3,4,5,6,7,8,9], index=list('awcdefghj'))
x = nums[nums > 5]
x * 2
# Out:
# f    12
# g    14
# h    16
# j    18
# dtype: int64

# %%
data = {
    "Name": ["John","Mary","Peter", "Alice"],
    "Age": [20,19,21, 22],
    "Marks": [85,90,78, 88],
    
}

df = pd.DataFrame(data, index=list('abcd'))

print(df)
# Out:
#     Name  Age  Marks
# a   John   20     85
# b   Mary   19     90
# c  Peter   21     78
# d  Alice   22     88

# %%
df.head()
# Out:
#   TransactionID        Date    Region     ProductCategory CustomerType  Sales  \
# 0        TX0001  2026-06-16   Eastern         Electronics    Wholesale   4924
# 1        TX0002  2026-02-12   Central         Electronics       Retail   3283
# 2        TX0003  2026-03-01  Northern                Food       Online   4049
# 3        TX0004  2026-06-03   Western  Household Products       Online   4331
# 4        TX0005  2026-01-21   Western  Household Products       Retail   3283
#
#    Profit
# 0  359.44
# 1  944.32
# 2  967.10
# 3  434.57
# 4  340.48

# %%
data = "ecommerce_bigdata.csv"
df = pd.read_csv(data)
df.describe()
# Out:
#              Sales       Profit
# count   200.000000   200.000000
# mean   2567.190000   456.367350
# std    1528.736925   346.853151
# min      56.000000     5.130000
# 25%    1200.500000   173.967500
# 50%    2428.000000   379.330000
# 75%    4052.000000   675.000000
# max    4998.000000  1377.040000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    200 non-null    str
#  1   Date             200 non-null    str
#  2   Region           200 non-null    str
#  3   ProductCategory  200 non-null    str
#  4   CustomerType     200 non-null    str
#  5   Sales            200 non-null    int64
#  6   Profit           200 non-null    float64
# dtypes: float64(1), int64(1), str(5)
# memory usage: 11.1 KB

# %%
print(df.columns)
print(df.dtypes)
# Out:
# Index(['TransactionID', 'Date', 'Region', 'ProductCategory', 'CustomerType',
#        'Sales', 'Profit'],
#       dtype='str')
# TransactionID          str
# Date                   str
# Region                 str
# ProductCategory        str
# CustomerType           str
# Sales                int64
# Profit             float64
# dtype: object

# %%
df.row

# %%
df.isnull().sum()
# Out:
# TransactionID      0
# Date               0
# Region             0
# ProductCategory    0
# CustomerType       0
# Sales              0
# Profit             0
# dtype: int64

# %%
df[["Sales","Profit"]].head(4)
# Out:
#    Sales  Profit
# 0   4924  359.44
# 1   3283  944.32
# 2   4049  967.10
# 3   4331  434.57

# %%
df.iloc[23:30, 2:5]
# Out:
#       Region ProductCategory CustomerType
# 23   Eastern            Food    Wholesale
# 24  Northern     Electronics       Online
# 25   Eastern       Beverages    Wholesale
# 26   Eastern        Clothing    Wholesale
# 27  Northern        Clothing       Retail
# 28   Eastern        Clothing    Wholesale
# 29   Western       Beverages       Online

# %%
df.loc[2:5, ["Sales", "Profit"]]
# Out:
#    Sales  Profit
# 2   4049  967.10
# 3   4331  434.57
# 4   3283  340.48
# 5   1088  153.77

# %%
greater_salary = df[df["Sales"] > 4000]
greater_salary.head()
greater_salary.describe()
# Out:
#              Sales       Profit
# count    53.000000    53.000000
# mean   4490.433962   821.222264
# std     295.284316   336.504978
# min    4017.000000   238.150000
# 25%    4241.000000   510.680000
# 50%    4476.000000   834.870000
# 75%    4748.000000  1094.260000
# max    4998.000000  1377.040000

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
z = [10,20,30,40,50]
y = [10,70,43,54,65]
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")

plt.plot(x,y,marker = 'o',label = "one")  
plt.plot(x,z,marker = 's',label = "two")
plt.legend()

# %%
x = [1,2,3,4,5]
z = [10,20,30,40,50]
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")

plt.bar(x,y,label = "one")  
plt.legend()

# %%
x = [1,2,3,4,5]
z = [10,20,30,40,50]
y = [10,70,43,54,65]
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")

plt.hist(y,label = "one")  
plt.legend()

# %%
ages = [20,21,22,22,23,24,24,25,30,35,40]

plt.hist(ages)
plt.show()

# %%
x = [1,2,3,4,5]
z = [10,20,30,40,50, 500]
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")

plt.scatter(x,y,label = "one")  
plt.legend()

# %%
plt.boxplot(y)
plt.show()

# %%
ages = [20,21,22,22,23,24,24,25,30,35,40]
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.hist(ages)
plt.show()

# %%
subjects = ["Math", "Physics", "Chemistry"]
marks = [80, 70, 90]

plt.bar(subjects, marks)
plt.title("Subject-wise Marks")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.grid(True)
plt.Figure(figsize=(7, 4))
plt.savefig(r"C:\Users\user\OneDrive\Desktop\Subject_marks.png")
plt.show()
